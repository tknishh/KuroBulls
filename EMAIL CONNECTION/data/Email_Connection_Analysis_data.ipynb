# %%
#to-recieved / to-sent
import random

for i in range(1,300):
	y = random.randrange(40)
	print(y)

# returns int type

# %%
#From user mails
import random

for i in range (1,300):
  randNum = random.randint(1,300)
  Gmail = "201B"+ str(randNum) + "@juetguna.in"
  print(Gmail)

#returns string type

# %%
#To user mails 
import random 

for i in range (1,300):
  randNum = random.randint(1,300)
  mail = "201B" + str(randNum) + "@jueguna.in"
  print(mail)

# %%
import random

def userId():
  for i in range (1,300):
    randNum = random.randint(1,300)
    Gmail = "201B"+ str(randNum) + "@juetguna.in"
    print(Gmail)

def toUserId():
  for i in range (1,300):
    rNum = random.randint(1,300)
    mail = "201B" + str(rNum) + "@jueguna.in"
    print(mail)

def toRecieved():
  for i in range(1,300):
	  y = random.randrange(40)
	  print(y)
   
def toSent():
  for i in range(1,300):
    y = random.randrange(40)
    print(y)

# %%
import pandas as pd

lst = [userId(), toUserId(), toRecieved(), toSent()]
df = pd.DataFrame(lst)
print(df)
# Out:
#                      0
# 0  201B189@juetguna.in
# 1   201B261@jueguna.in
# 2                   27
# 3                   17

# %%
import random

def userId():
  for i in range (1,300):
    randNum = random.randint(1,300)
    Gmail = "201B"+ str(randNum) + "@juetguna.in"
    return(Gmail)

def toUserId():
  for i in range (1,300):
    rNum = random.randint(1,300)
    mail = "201B" + str(rNum) + "@jueguna.in"
    return(mail)

def toRecieved():
  for i in range(1,300):
	  y = random.randrange(40)
	  return(y)
   
def toSent():
  for i in range(1,300):
    y = random.randrange(40)
    return(y)

for i in range (1,300):
  lst = [userId(),toUserId(),toRecieved(),toSent()]
  print(lst)
# Out:
# ['201B82@juetguna.in', '201B171@jueguna.in', 25, 8]
# ['201B117@juetguna.in', '201B283@jueguna.in', 36, 2]
# ['201B246@juetguna.in', '201B19@jueguna.in', 32, 4]
# ['201B220@juetguna.in', '201B238@jueguna.in', 27, 7]
# ['201B9@juetguna.in', '201B31@jueguna.in', 27, 28]
# ['201B93@juetguna.in', '201B160@jueguna.in', 0, 19]
# ['201B247@juetguna.in', '201B46@jueguna.in', 30, 33]
# ['201B22@juetguna.in', '201B238@jueguna.in', 11, 4]
# ['201B182@juetguna.in', '201B99@jueguna.in', 15, 1]
# ['201B84@juetguna.in', '201B72@jueguna.in', 0, 3]
# ['201B272@juetguna.in', '201B11@jueguna.in', 13, 2]
# ['201B191@juetguna.in', '201B33@jueguna.in', 23, 39]
# ['201B75@juetguna.in', '201B229@jueguna.in', 36, 7]
# ['201B89@juetguna.in', '201B265@jueguna.in', 21, 13]
# ['201B146@juetguna.in', '201B281@jueguna.in', 31, 18]
# ['201B2@juetguna.in', '201B125@jueguna.in', 23, 9]
# ['201B153@juetguna.in', '201B8@jueguna.in', 37, 39]
# ['201B187@juetguna.in', '201B274@jueguna.in', 25, 17]
# ['201B55@juetguna.in', '201B198@jueguna.in', 0, 6]
# ['201B170@juetguna.in', '201B40@jueguna.in', 38, 36]
# ['201B268@juetguna.in', '201B157@jueguna.in', 16, 14]
# ['201B92@juetguna.in', '201B241@jueguna.in', 25, 14]
# ['201B135@juetguna.in', '201B54@jueguna.in', 33, 20]
# ['201B110@juetguna.in', '201B291@jueguna.in', 12, 31]
# ['201B151@juetguna.in', '201B263@jueguna.in', 7, 17]
# ['201B210@juetguna.in', '201B87@jueguna.in', 10, 7]
# ['201B266@juetguna.in', '201B138@jueguna.in', 25, 35]
# ['201B275@juetguna.in', '201B274@jueguna.in', 11, 22]
# ['201B271@juetguna.in', '201B111@jueguna.in', 35, 31]
# ['201B286@juetguna.in', '201B224@jueguna.in', 20, 4]
# ['201B266@juetguna.in', '201B6@jueguna.in', 16, 1]
# ['201B257@juetguna.in', '201B188@jueguna.in', 3, 6]
# ['201B88@juetguna.in', '201B273@jueguna.in', 16, 31]
# ['201B198@juetguna.in', '201B46@jueguna.in', 2, 35]
# ['201B86@juetguna.in', '201B138@jueguna.in', 11, 21]
# ['201B132@juetguna.in', '201B47@jueguna.in', 30, 5]
# ['201B55@juetguna.in', '201B63@jueguna.in', 16, 35]
# ['201B12@juetguna.in', '201B41@jueguna.in', 9, 31]
# ['201B72@juetguna.in', '201B108@jueguna.in', 31, 26]
# ['201B13@juetguna.in', '201B79@jueguna.in', 24, 8]
# ['201B174@juetguna.in', '201B131@jueguna.in', 35, 7]
# ['201B2@juetguna.in', '201B242@jueguna.in', 28, 24]
# ['201B281@juetguna.in', '201B298@jueguna.in', 30, 27]
# ['201B155@juetguna.in', '201B4@jueguna.in', 8, 38]
# ['201B162@juetguna.in', '201B58@jueguna.in', 35, 6]
# ['201B271@juetguna.in', '201B52@jueguna.in', 33, 3]
# ['201B71@juetguna.in', '201B101@jueguna.in', 34, 19]
# ['201B287@juetguna.in', '201B117@jueguna.in', 15, 26]
# ['201B207@juetguna.in', '201B277@jueguna.in', 37, 10]
# ['201B38@juetguna.in', '201B167@jueguna.in', 20, 11]
# ['201B201@juetguna.in', '201B179@jueguna.in', 6, 38]
# ['201B97@juetguna.in', '201B278@jueguna.in', 39, 7]
# ['201B299@juetguna.in', '201B173@jueguna.in', 22, 31]
# ['201B174@juetguna.in', '201B20@jueguna.in', 6, 23]
# ['201B169@juetguna.in', '201B38@jueguna.in', 39, 2]
# ['201B295@juetguna.in', '201B108@jueguna.in', 22, 2]
# ['201B15@juetguna.in', '201B126@jueguna.in', 33, 37]
# ['201B233@juetguna.in', '201B288@jueguna.in', 17, 11]
# ['201B294@juetguna.in', '201B199@jueguna.in', 14, 8]
# ['201B195@juetguna.in', '201B98@jueguna.in', 1, 4]
# ['201B263@juetguna.in', '201B261@jueguna.in', 8, 23]
# ['201B253@juetguna.in', '201B179@jueguna.in', 4, 7]
# ['201B121@juetguna.in', '201B260@jueguna.in', 15, 23]
# ['201B49@juetguna.in', '201B100@jueguna.in', 24, 12]
# ['201B19@juetguna.in', '201B270@jueguna.in', 26, 1]
# ['201B75@juetguna.in', '201B201@jueguna.in', 23, 25]
# ['201B48@juetguna.in', '201B85@jueguna.in', 16, 32]
# ['201B214@juetguna.in', '201B288@jueguna.in', 24, 7]
# ['201B243@juetguna.in', '201B37@jueguna.in', 17, 0]
# ['201B88@juetguna.in', '201B205@jueguna.in', 19, 39]
# ['201B292@juetguna.in', '201B120@jueguna.in', 3, 3]
# ['201B244@juetguna.in', '201B4@jueguna.in', 18, 18]
# ['201B137@juetguna.in', '201B188@jueguna.in', 30, 0]
# ['201B132@juetguna.in', '201B229@jueguna.in', 15, 18]
# ['201B49@juetguna.in', '201B38@jueguna.in', 15, 16]
# ['201B273@juetguna.in', '201B274@jueguna.in', 1, 9]
# ['201B157@juetguna.in', '201B243@jueguna.in', 39, 32]
# ['201B94@juetguna.in', '201B167@jueguna.in', 5, 28]
# ['201B286@juetguna.in', '201B200@jueguna.in', 15, 16]
# ['201B234@juetguna.in', '201B33@jueguna.in', 2, 5]
# ['201B88@juetguna.in', '201B108@jueguna.in', 14, 3]
# ['201B154@juetguna.in', '201B4@jueguna.in', 31, 39]
# ['201B100@juetguna.in', '201B127@jueguna.in', 6, 4]
# ['201B294@juetguna.in', '201B211@jueguna.in', 37, 4]
# ['201B153@juetguna.in', '201B6@jueguna.in', 36, 32]
# ['201B113@juetguna.in', '201B191@jueguna.in', 1, 7]
# ['201B39@juetguna.in', '201B194@jueguna.in', 5, 31]
# ['201B152@juetguna.in', '201B90@jueguna.in', 8, 11]
# ['201B253@juetguna.in', '201B201@jueguna.in', 5, 28]
# ['201B283@juetguna.in', '201B57@jueguna.in', 7, 30]
# ['201B187@juetguna.in', '201B102@jueguna.in', 25, 25]
# ['201B20@juetguna.in', '201B50@jueguna.in', 2, 30]
# ['201B137@juetguna.in', '201B220@jueguna.in', 8, 11]
# ['201B290@juetguna.in', '201B55@jueguna.in', 21, 16]
# ['201B130@juetguna.in', '201B249@jueguna.in', 28, 36]
# ['201B64@juetguna.in', '201B84@jueguna.in', 33, 32]
# ['201B162@juetguna.in', '201B191@jueguna.in', 35, 23]
# ['201B226@juetguna.in', '201B250@jueguna.in', 34, 13]
# ['201B51@juetguna.in', '201B83@jueguna.in', 5, 12]
# ['201B283@juetguna.in', '201B67@jueguna.in', 10, 15]
# ['201B60@juetguna.in', '201B25@jueguna.in', 22, 7]
# ['201B293@juetguna.in', '201B10@jueguna.in', 31, 16]
# ['201B137@juetguna.in', '201B219@jueguna.in', 24, 16]
# ['201B256@juetguna.in', '201B73@jueguna.in', 13, 19]
# ['201B95@juetguna.in', '201B222@jueguna.in', 36, 18]
# ['201B158@juetguna.in', '201B44@jueguna.in', 29, 19]
# ['201B151@juetguna.in', '201B23@jueguna.in', 33, 27]
# ['201B250@juetguna.in', '201B239@jueguna.in', 8, 10]
# ['201B208@juetguna.in', '201B75@jueguna.in', 24, 6]
# ['201B9@juetguna.in', '201B193@jueguna.in', 9, 21]
# ['201B162@juetguna.in', '201B66@jueguna.in', 13, 30]
# ['201B290@juetguna.in', '201B145@jueguna.in', 1, 37]
# ['201B107@juetguna.in', '201B37@jueguna.in', 12, 0]
# ['201B64@juetguna.in', '201B48@jueguna.in', 23, 28]
# ['201B228@juetguna.in', '201B292@jueguna.in', 25, 33]
# ['201B143@juetguna.in', '201B156@jueguna.in', 39, 11]
# ['201B156@juetguna.in', '201B1@jueguna.in', 14, 28]
# ['201B41@juetguna.in', '201B38@jueguna.in', 10, 28]
# ['201B132@juetguna.in', '201B262@jueguna.in', 22, 38]
# ['201B180@juetguna.in', '201B287@jueguna.in', 34, 27]
# ['201B47@juetguna.in', '201B190@jueguna.in', 32, 7]
# ['201B165@juetguna.in', '201B299@jueguna.in', 37, 13]
# ['201B221@juetguna.in', '201B43@jueguna.in', 20, 5]
# ['201B240@juetguna.in', '201B10@jueguna.in', 11, 34]
# ['201B149@juetguna.in', '201B280@jueguna.in', 21, 31]
# ['201B271@juetguna.in', '201B222@jueguna.in', 20, 17]
# ['201B103@juetguna.in', '201B22@jueguna.in', 27, 36]
# ['201B299@juetguna.in', '201B58@jueguna.in', 6, 12]
# ['201B73@juetguna.in', '201B52@jueguna.in', 37, 34]
# ['201B99@juetguna.in', '201B91@jueguna.in', 39, 33]
# ['201B33@juetguna.in', '201B263@jueguna.in', 19, 30]
# ['201B31@juetguna.in', '201B209@jueguna.in', 32, 0]
# ['201B1@juetguna.in', '201B70@jueguna.in', 31, 21]
# ['201B16@juetguna.in', '201B178@jueguna.in', 1, 2]
# ['201B99@juetguna.in', '201B98@jueguna.in', 20, 37]
# ['201B48@juetguna.in', '201B135@jueguna.in', 27, 1]
# ['201B78@juetguna.in', '201B57@jueguna.in', 16, 32]
# ['201B174@juetguna.in', '201B231@jueguna.in', 4, 28]
# ['201B8@juetguna.in', '201B33@jueguna.in', 33, 26]
# ['201B281@juetguna.in', '201B108@jueguna.in', 11, 19]
# ['201B166@juetguna.in', '201B195@jueguna.in', 15, 27]
# ['201B245@juetguna.in', '201B141@jueguna.in', 37, 32]
# ['201B23@juetguna.in', '201B213@jueguna.in', 27, 17]
# ['201B232@juetguna.in', '201B37@jueguna.in', 19, 8]
# ['201B42@juetguna.in', '201B132@jueguna.in', 38, 28]
# ['201B81@juetguna.in', '201B163@jueguna.in', 23, 5]
# ['201B80@juetguna.in', '201B16@jueguna.in', 22, 7]
# ['201B106@juetguna.in', '201B249@jueguna.in', 2, 20]
# ['201B213@juetguna.in', '201B193@jueguna.in', 38, 20]
# ['201B40@juetguna.in', '201B136@jueguna.in', 24, 39]
# ['201B29@juetguna.in', '201B276@jueguna.in', 9, 3]
# ['201B3@juetguna.in', '201B119@jueguna.in', 4, 9]
# ['201B122@juetguna.in', '201B238@jueguna.in', 13, 21]
# ['201B111@juetguna.in', '201B202@jueguna.in', 13, 12]
# ['201B151@juetguna.in', '201B270@jueguna.in', 17, 20]
# ['201B200@juetguna.in', '201B178@jueguna.in', 2, 20]
# ['201B219@juetguna.in', '201B181@jueguna.in', 37, 23]
# ['201B16@juetguna.in', '201B162@jueguna.in', 24, 3]
# ['201B18@juetguna.in', '201B278@jueguna.in', 11, 3]
# ['201B261@juetguna.in', '201B105@jueguna.in', 21, 10]
# ['201B58@juetguna.in', '201B209@jueguna.in', 30, 6]
# ['201B48@juetguna.in', '201B294@jueguna.in', 37, 7]
# ['201B205@juetguna.in', '201B285@jueguna.in', 2, 12]
# ['201B194@juetguna.in', '201B285@jueguna.in', 26, 27]
# ['201B57@juetguna.in', '201B57@jueguna.in', 37, 14]
# ['201B10@juetguna.in', '201B294@jueguna.in', 33, 9]
# ['201B101@juetguna.in', '201B198@jueguna.in', 4, 12]
# ['201B198@juetguna.in', '201B30@jueguna.in', 17, 18]
# ['201B18@juetguna.in', '201B234@jueguna.in', 37, 14]
# ['201B146@juetguna.in', '201B105@jueguna.in', 28, 7]
# ['201B120@juetguna.in', '201B239@jueguna.in', 8, 20]
# ['201B260@juetguna.in', '201B131@jueguna.in', 36, 30]
# ['201B222@juetguna.in', '201B37@jueguna.in', 17, 15]
# ['201B71@juetguna.in', '201B120@jueguna.in', 6, 24]
# ['201B111@juetguna.in', '201B73@jueguna.in', 18, 7]
# ['201B154@juetguna.in', '201B159@jueguna.in', 39, 27]
# ['201B169@juetguna.in', '201B96@jueguna.in', 2, 0]
# ['201B156@juetguna.in', '201B257@jueguna.in', 38, 19]
# ['201B144@juetguna.in', '201B295@jueguna.in', 6, 4]
# ['201B148@juetguna.in', '201B264@jueguna.in', 33, 10]
# ['201B106@juetguna.in', '201B193@jueguna.in', 39, 32]
# ['201B150@juetguna.in', '201B247@jueguna.in', 3, 34]
# ['201B90@juetguna.in', '201B131@jueguna.in', 19, 36]
# ['201B36@juetguna.in', '201B195@jueguna.in', 0, 20]
# ['201B268@juetguna.in', '201B88@jueguna.in', 8, 33]
# ['201B219@juetguna.in', '201B266@jueguna.in', 3, 31]
# ['201B246@juetguna.in', '201B44@jueguna.in', 32, 32]
# ['201B158@juetguna.in', '201B81@jueguna.in', 5, 22]
# ['201B170@juetguna.in', '201B20@jueguna.in', 11, 25]
# ['201B244@juetguna.in', '201B135@jueguna.in', 34, 30]
# ['201B58@juetguna.in', '201B15@jueguna.in', 4, 1]
# ['201B55@juetguna.in', '201B221@jueguna.in', 14, 32]
# ['201B80@juetguna.in', '201B254@jueguna.in', 10, 32]
# ['201B141@juetguna.in', '201B57@jueguna.in', 33, 7]
# ['201B185@juetguna.in', '201B296@jueguna.in', 8, 25]
# ['201B124@juetguna.in', '201B33@jueguna.in', 20, 34]
# ['201B295@juetguna.in', '201B75@jueguna.in', 17, 28]
# ['201B218@juetguna.in', '201B67@jueguna.in', 23, 0]
# ['201B297@juetguna.in', '201B264@jueguna.in', 14, 7]
# ['201B271@juetguna.in', '201B168@jueguna.in', 0, 22]
# ['201B245@juetguna.in', '201B231@jueguna.in', 10, 38]
# ['201B26@juetguna.in', '201B51@jueguna.in', 4, 11]
# ['201B231@juetguna.in', '201B37@jueguna.in', 14, 35]
# ['201B229@juetguna.in', '201B71@jueguna.in', 24, 16]
# ['201B143@juetguna.in', '201B86@jueguna.in', 8, 1]
# ['201B215@juetguna.in', '201B164@jueguna.in', 36, 9]
# ['201B47@juetguna.in', '201B175@jueguna.in', 27, 13]
# ['201B269@juetguna.in', '201B138@jueguna.in', 27, 31]
# ['201B234@juetguna.in', '201B31@jueguna.in', 5, 3]
# ['201B220@juetguna.in', '201B148@jueguna.in', 9, 17]
# ['201B297@juetguna.in', '201B75@jueguna.in', 39, 17]
# ['201B83@juetguna.in', '201B165@jueguna.in', 36, 13]
# ['201B159@juetguna.in', '201B28@jueguna.in', 20, 6]
# ['201B195@juetguna.in', '201B207@jueguna.in', 18, 39]
# ['201B174@juetguna.in', '201B159@jueguna.in', 26, 0]
# ['201B239@juetguna.in', '201B124@jueguna.in', 33, 33]
# ['201B12@juetguna.in', '201B202@jueguna.in', 36, 28]
# ['201B141@juetguna.in', '201B78@jueguna.in', 6, 24]
# ['201B81@juetguna.in', '201B286@jueguna.in', 2, 1]
# ['201B102@juetguna.in', '201B53@jueguna.in', 6, 2]
# ['201B234@juetguna.in', '201B39@jueguna.in', 21, 33]
# ['201B276@juetguna.in', '201B141@jueguna.in', 35, 30]
# ['201B8@juetguna.in', '201B244@jueguna.in', 8, 9]
# ['201B61@juetguna.in', '201B130@jueguna.in', 22, 20]
# ['201B34@juetguna.in', '201B27@jueguna.in', 27, 6]
# ['201B95@juetguna.in', '201B201@jueguna.in', 20, 22]
# ['201B211@juetguna.in', '201B73@jueguna.in', 34, 4]
# ['201B270@juetguna.in', '201B165@jueguna.in', 11, 27]
# ['201B65@juetguna.in', '201B146@jueguna.in', 7, 2]
# ['201B22@juetguna.in', '201B228@jueguna.in', 28, 35]
# ['201B197@juetguna.in', '201B266@jueguna.in', 19, 20]
# ['201B77@juetguna.in', '201B227@jueguna.in', 10, 26]
# ['201B250@juetguna.in', '201B281@jueguna.in', 6, 38]
# ['201B237@juetguna.in', '201B220@jueguna.in', 17, 16]
# ['201B19@juetguna.in', '201B142@jueguna.in', 26, 3]
# ['201B18@juetguna.in', '201B277@jueguna.in', 25, 19]
# ['201B20@juetguna.in', '201B25@jueguna.in', 35, 36]
# ['201B271@juetguna.in', '201B29@jueguna.in', 25, 13]
# ['201B27@juetguna.in', '201B116@jueguna.in', 32, 39]
# ['201B119@juetguna.in', '201B229@jueguna.in', 28, 10]
# ['201B163@juetguna.in', '201B84@jueguna.in', 10, 37]
# ['201B133@juetguna.in', '201B224@jueguna.in', 28, 19]
# ['201B202@juetguna.in', '201B139@jueguna.in', 19, 32]
# ['201B11@juetguna.in', '201B153@jueguna.in', 35, 17]
# ['201B141@juetguna.in', '201B296@jueguna.in', 16, 26]
# ['201B50@juetguna.in', '201B290@jueguna.in', 35, 3]
# ['201B49@juetguna.in', '201B15@jueguna.in', 30, 25]
# ['201B190@juetguna.in', '201B229@jueguna.in', 11, 16]
# ['201B238@juetguna.in', '201B265@jueguna.in', 22, 39]
# ['201B98@juetguna.in', '201B37@jueguna.in', 15, 15]
# ['201B95@juetguna.in', '201B48@jueguna.in', 27, 22]
# ['201B95@juetguna.in', '201B258@jueguna.in', 11, 9]
# ['201B128@juetguna.in', '201B31@jueguna.in', 27, 5]
# ['201B35@juetguna.in', '201B3@jueguna.in', 26, 38]
# ['201B42@juetguna.in', '201B172@jueguna.in', 35, 9]
# ['201B207@juetguna.in', '201B134@jueguna.in', 37, 21]
# ['201B31@juetguna.in', '201B207@jueguna.in', 35, 4]
# ['201B206@juetguna.in', '201B232@jueguna.in', 10, 31]
# ['201B51@juetguna.in', '201B227@jueguna.in', 37, 22]
# ['201B241@juetguna.in', '201B157@jueguna.in', 36, 25]
# ['201B62@juetguna.in', '201B132@jueguna.in', 22, 18]
# ['201B183@juetguna.in', '201B80@jueguna.in', 17, 25]
# ['201B284@juetguna.in', '201B95@jueguna.in', 36, 37]
# ['201B35@juetguna.in', '201B56@jueguna.in', 24, 5]
# ['201B258@juetguna.in', '201B183@jueguna.in', 11, 20]
# ['201B234@juetguna.in', '201B23@jueguna.in', 14, 26]
# ['201B190@juetguna.in', '201B99@jueguna.in', 0, 8]
# ['201B36@juetguna.in', '201B196@jueguna.in', 27, 26]
# ['201B169@juetguna.in', '201B286@jueguna.in', 7, 29]
# ['201B15@juetguna.in', '201B285@jueguna.in', 29, 38]
# ['201B193@juetguna.in', '201B160@jueguna.in', 7, 33]
# ['201B76@juetguna.in', '201B196@jueguna.in', 34, 32]
# ['201B191@juetguna.in', '201B110@jueguna.in', 16, 7]
# ['201B153@juetguna.in', '201B125@jueguna.in', 29, 38]
# ['201B59@juetguna.in', '201B202@jueguna.in', 33, 23]
# ['201B252@juetguna.in', '201B105@jueguna.in', 9, 0]
# ['201B23@juetguna.in', '201B69@jueguna.in', 11, 35]
# ['201B28@juetguna.in', '201B87@jueguna.in', 34, 13]
# ['201B72@juetguna.in', '201B146@jueguna.in', 28, 20]
# ['201B54@juetguna.in', '201B199@jueguna.in', 35, 36]
# ['201B92@juetguna.in', '201B12@jueguna.in', 38, 38]
# ['201B289@juetguna.in', '201B220@jueguna.in', 13, 21]
# ['201B91@juetguna.in', '201B91@jueguna.in', 38, 14]
# ['201B298@juetguna.in', '201B154@jueguna.in', 21, 6]
# ['201B173@juetguna.in', '201B34@jueguna.in', 25, 25]
# ['201B51@juetguna.in', '201B258@jueguna.in', 18, 20]
# ['201B175@juetguna.in', '201B138@jueguna.in', 16, 28]
# ['201B199@juetguna.in', '201B121@jueguna.in', 8, 10]
# ['201B276@juetguna.in', '201B99@jueguna.in', 20, 4]
# ['201B79@juetguna.in', '201B189@jueguna.in', 0, 14]
# ['201B13@juetguna.in', '201B89@jueguna.in', 11, 22]
# ['201B248@juetguna.in', '201B188@jueguna.in', 19, 26]
# ['201B9@juetguna.in', '201B132@jueguna.in', 11, 23]
# ['201B13@juetguna.in', '201B33@jueguna.in', 13, 4]
# ['201B280@juetguna.in', '201B230@jueguna.in', 34, 39]
# ['201B17@juetguna.in', '201B264@jueguna.in', 12, 26]
# ['201B63@juetguna.in', '201B107@jueguna.in', 31, 10]
# ['201B6@juetguna.in', '201B199@jueguna.in', 28, 37]
# ['201B178@juetguna.in', '201B268@jueguna.in', 11, 27]

# %%
import numpy as np
import pandas as pd

arr = np.array(lst)
arr.resize(4,4)

df = pd.DataFrame(arr, columns = ['User-Id', 'To-User-Id', 'to-recieved', 'To-sent'])
print(df)
# Out:
#                User-Id          To-User-Id to-recieved To-sent
# 0  201B178@juetguna.in  201B268@jueguna.in          11      27
# 1
# 2
# 3
